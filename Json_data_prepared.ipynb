# %% [markdown]
# ## Games Data

# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO
import pandas as pd
import datetime as dt
#TO_DO: add packages related to AWS later to upload stuff there

# %% [markdown]
# Here we filter out certain events in our game json data, because they don't seem to be relevant/ or will biase our model

# %%
def filter_out_events(game_event):

    event_filter = ['stats_update','item_purchased','item_destroyed',
                    'item_undo','item_sold','skill_level_up' ,'ward_placed', 'champion_level_up']

    #No event found: either it's messy data, or there's nothing to record.
    if game_event.get('eventType',None) is None:
        return False
    return (game_event.get('eventType',None) not in event_filter)

# %% [markdown]
# Here we create a function that takes in input a dictionnary of a game event and gives in output the keys that we'll need in our model

# %%
def GameEvent_Processing(game_event):
    """
    Process a game event dictionary to extract and format relevant data for a model.

    The function examines the 'eventType' within the game event data to structure
    the output according to the event type, such as game information, turret destruction,
    jungle monster kills, champion kills, stats updates, and game end events. Unnecessary keys
    are removed, and team IDs are converted to team colors. The function outputs a dictionary
    tailored to include only the keys needed for the model's input.

    Parameters:
    game_event (dict): A dictionary representing the game event data.

    Returns:
    dict: A processed dictionary with structured data for model input or the original
          game event data if no processing is done.
    """
    processed_output=None
    eventtype=game_event.get('eventType')
    def convert_team_id(teamID):
        if teamID == 200:
            return 'red'
        elif teamID == 100:
            return 'blue'

        return None
    keys_to_remove = ['eventTime','eventType','platformGameId','gameTime',
                      'stageID','sequenceIndex','gameName','playbackID']
    for key in keys_to_remove:
        game_event.pop(key,None)


    # first eventtype, always game_info :
    #"eventType": "game_info", "platformGameId": "ESPORTSTMNT01:3363718", "participants": [{"keystoneID": 8021, "hashedIP": "3VoTUXLOxMy1OmdTUitHpqfdYIc=", "teamID": 100, "participantID": 1, "championName": "Graves", "accountID": 2799125876114848, "abGroup": "", "perks": [{"perkIds": [8021, 8009, 9103, 8299, 8242, 8473, 5005, 5008, 5002], "perkStyle": 8000, "perkSubStyle": 8400}], "summonerName": "ECG Nate", "summonerLevel": 30}

    if eventtype =='game_info':
        blue_team=[]
        red_team=[]
        for player_dict in game_event.get('participants',None):
            player_info={
                'participantID': player_dict.get('participantID', None),
                'summonerName': player_dict.get('summonerName',None),
                'championName': player_dict.get('championName',None)
      }
            team_side = player_dict.get('teamID',None)
            if team_side == 100:
                blue_team.append(player_info)
            elif team_side == 200:
                red_team.append(player_info)
        processed_output = {
        'blue': blue_team,
        'red': red_team
    }
    # plating
    if eventtype == 'turret_plate_destroyed':
        processed_output = {
        'team': convert_team_id(game_event.get('teamID')),
        'lane': game_event.get('lane')
    }
        
    # turret destroyed   
    if eventtype == 'building_destroyed':
        processed_output = {
        'team': convert_team_id(game_event.get('teamID')),
        'lane': game_event.get('lane'),
        'buildingType': game_event.get('buildingType')
    }
    if game_event.get('turretTier',None):
      processed_output.update({'turretTier': game_event.get('turretTier')})

  #Jungle monster kills:
    if eventtype == 'epic_monster_kill':
      processed_output = {
        'monsterType': game_event.get('monsterType'),
        'killer': game_event.get('killer'),
        'team': convert_team_id(game_event.get('killerteamID')),
        'inEnemyJungle': game_event.get('inEnemyJungle'),
    }


  #Deliberate champion kills
    if eventtype == 'champion_kill':
      processed_output = {
        'killerTeam': convert_team_id(game_event.get('killerTeamID',None)),
        'victimTeam': convert_team_id(game_event.get('victimTeamID',None)),
        'killer': game_event.get('killer'),
        'assistants': game_event.get('assistants'),
        'position': game_event.get('position')
    }


  #Stats updates
    if eventtype == 'stats_update':

      tracked_stats = ['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS', 'TOTAL_DAMAGE_TAKEN',
                     'TIME_CCING_OTHERS', 'VISION_SCORE',
                     'NEUTRAL_MINIONS_KILLED',
                     'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE',
                     'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE']

      info_dump = []

      for participant in game_event.get('participants'):
      #All participants have specific data points that we want to acquire
        participant_data = {
          'participantID': participant.get('participantID'),
          'XP': participant.get('XP'),
          'totalGold': participant.get('totalGold'),
      }

      #We also want specific stats to appear in our data log:
        for stat_category in participant['stats']:

          if stat_category.get('name') in tracked_stats:
            participant_data.update({stat_category.get('name'):
                                  stat_category.get('value')})

        info_dump.append(participant_data)

      blue_status = None
      red_status = None
      team_status = game_event.get('teams',None)

      for side in team_status:
        indicator = side.pop('teamID')
        if indicator == 100:
          blue_status = side
        elif indicator == 200:
          red_status = side
      
          

    #Afterwards, we ship it alongside the teams info (which might be redundant)
      processed_output = {
      'participants':info_dump,
      'blue': blue_status,
      'red': red_status
    }

  #Endgame event contains the winner:
    if eventtype == 'game_end':
      processed_output = {'winningTeam':
                        convert_team_id(game_event.get('winningTeam',None))}


    if processed_output:
      return processed_output


    return game_event

# %%
def process_game(game_json):
  """
    Process a JSON array of game events and compile a list of essential events for game analysis.

    The function starts by recording the initial game information such as timestamp, platform ID, 
    and patch version. It then iterates over each game event, converting timestamps and filtering
    events based on specific criteria. Key game moments such as 10 and 15-minute marks, as well as 
    endgame stats, are specifically tracked and recorded. The output is an event list that contains 
    structured data for each relevant game event, providing a timeline of the game for subsequent analysis.

    Parameters:
    game_json (list of dicts): A JSON array where each element is a dictionary representing a game event.

    Returns:
    list: A list of dictionaries, each containing structured data for a key game event, including 
          time of the event, event type, and processed event data.
    """
  event_list = []

  #Take data that describes our game at the moment:
  initial_timestamp = game_json[0].get('eventTime')
  platform_id = game_json[0].get('platformGameId')
  patch_info = game_json[0].get('gameVersion')
  event_list.append({
      'gameDate': initial_timestamp,
      'esportsPlatformId': platform_id,
      'gameVersion': patch_info
  })

  #Convert our timestamp for use in the upcoming game log
  initial_timestamp = dt.datetime.fromisoformat(initial_timestamp.replace('Z','+00:00'))

  #Which stat updates do we want to record?
  stat_update_obtained = {
      600:False, #10-minute updates
      900:False, #15-minute updates
      'Endgame':False #Final game update
  }

  for game_event in game_json:

      event_timestamp = game_event.get('eventTime')
      event_timestamp = dt.datetime.fromisoformat(event_timestamp.replace('Z','+00:00'))
      game_timer = (event_timestamp - initial_timestamp) / dt.timedelta(seconds=1)

      def build_event_dict(my_timestamp,current_event,label=None):
        event_label =  label if label is not None else current_event.get('eventType',None)
        processed_event = GameEvent_Processing(current_event)
        output_dict = {
            'gameTime': my_timestamp,
            'eventType': event_label
        }
        output_dict.update(processed_event)
        return output_dict

      if filter_out_events(game_event):
        event_list.append(build_event_dict(game_timer,game_event))

      elif game_event.get('eventType',None) == 'stats_update':

          #10-minute mark stat update
          if not stat_update_obtained[600] and (game_timer>=600):
            event_list.append(build_event_dict(game_timer,game_event,
                                              'game_state_10mn'))
            stat_update_obtained[600]=True

          #15-minute mark stat update
          if not stat_update_obtained[900] and (game_timer>=900):
            event_list.append(build_event_dict(game_timer,game_event,
                                                'game_state_15mn'))
            stat_update_obtained[900]=True

          #Endgame stat update
          if not stat_update_obtained['Endgame'] and game_event.get('gameOver',False):
            event_list.append(build_event_dict(game_timer,game_event,
                                                'game_state_end'))
            stat_update_obtained['Endgame']=True
  return event_list

# %%
from json import JSONDecodeError
from tqdm import tqdm
from itertools import islice

dossier_games = 'games'
dossier_esports = 'esports-data'

with open("./esports-data/mapping_data.json", 'r') as mapping_file:
    mappings_data_list = json.load(mapping_file)

mappings_data = {item['platformGameId']: item for item in mappings_data_list}

# List only files with the `.json` extension without building intermediary lists
games = (f for f in os.listdir(dossier_games) if os.path.isfile(os.path.join(dossier_games, f)) and f.endswith('.json') and os.path.getsize(os.path.join(dossier_games, f)) > 1048576) 
games_to_process = islice(games, 203, None)
for game in tqdm(games):

    chemin_complet = os.path.join(dossier_games, game)
    try :
        with open(chemin_complet, 'r') as f:
            game_json = json.load(f)
    except JSONDecodeError as e:
        print(f"File {game} got unexpected error : {e}")

    try :
        game_json_filtered=process_game(game_json)
        with open(chemin_complet, 'w') as f:
            json.dump(game_json_filtered,f)
    
        # Vous pouvez choisir d'ignorer ce fichier, de le sauvegarder ailleurs, etc.
    except AttributeError:
        print(f'The game {game} has been already modified')
# Out:
# 1it [00:00,  1.48it/s]
# File ESPORTSTMNT02_3170169.json got unexpected error : Unterminated string starting at: line 1 column 30408700 (char 30408699)
# The game ESPORTSTMNT02_3170169.json has been already modified
# 2it [00:02,  1.38s/it]
# File ESPORTSTMNT02_3170174.json got unexpected error : Expecting ':' delimiter: line 1 column 103809025 (char 103809024)
# The game ESPORTSTMNT02_3170174.json has been already modified
# 2it [00:02,  1.41s/it]

# %% [markdown]
# ## Leagues Data

# %%
#Alternatively:
def filter_bad_tournaments():
    #If we haven't pre-cleaned things:
    if not os.path.isfile('esports-data/leagues-cleaned.json'):
        leagues_df = pd.read_json('esports-data/leagues.json')
        #Clear TFT and All-Star tournaments from our leagues
        try:
            leagues_df.drop(axis=0,labels=[37,17],inplace=True)
        except:
            print('We have already cleared the rows related to All-Star and TFT.')
        #Drop extraneous columns
        try:
            leagues_df.drop(axis=1, columns=['displayPriority','image','sport',
                                            'lightImage','darkImage','slug'],
                            inplace=True)
        except:
            print('We have already cleared the columns that we did not need.')
        leagues_df.to_json('esports-data/leagues-cleaned.json')

# %%
leagues_df=pd.read_json('./esports-data/leagues-cleaned.json')
leages_df
# Out:
#                     id                        name  \
# 0    98767991299243168                         LCS
# 1   109511549831443328             LCS Challengers
# 2   109518549825754240  LCS Challengers Qualifiers
# 3   107898214974993344        College Championship
# 4    98767991332355504                       CBLOL
# 5    98767991310872064                         LCK
# 6    98767991355908944                         LCL
# 7   105709090213554608                         LCO
# 8    98767991302996016                         LEC
# 9    98767991349978720                         LJL
# 10  101382741235120464                         LLA
# 11   98767991314006704                         LPL
# 12  104366947889790208                         PCS
# 13   98767991343597632                         TCL
# 14  107213827295848784                         VCS
# 15   98767991325878496                         MSI
# 16   98767975604431408                      Worlds
# 18  100695891328981120                EMEA Masters
# 19  105266103462388560          La Ligue Française
# 20  105266098308571968                         NLC
# 21  107407335299756368                Elite Series
# 22  105266101075764032             Liga Portuguesa
# 23  105266094998946944                PG Nationals
# 24  105266088231437424                   Ultraliga
# 25  105266074488398656                   SuperLiga
# 26  105266091639104320                Prime League
# 27  105266106309666624            Hitpoint Masters
# 28  105266111679554384       Esports Balkan League
# 29  105266108767593296        Greek Legends League
# 30  109545772895506416              Arabian League
# 31  108203770023880320                 LCK Academy
# 32  106827757669296912                 LJL Academy
# 33   98767991335774720             LCK Challengers
# 34  105549980953490848               CBLOL Academy
# 35  110371976858004496       North Regional League
# 36  110372322609949920       South Regional League
#
#                                 region  priority  \
# 0                        NORTH AMERICA         1
# 1                        NORTH AMERICA      1000
# 2                        NORTH AMERICA      1000
# 3                        NORTH AMERICA      1000
# 4                               BRAZIL       204
# 5                                KOREA         4
# 6   COMMONWEALTH OF INDEPENDENT STATES       209
# 7                              OCEANIA       207
# 8                                 EMEA         3
# 9                                JAPAN       208
# 10                       LATIN AMERICA       206
# 11                               CHINA       201
# 12            HONG KONG, MACAU, TAIWAN      1000
# 13                                EMEA       203
# 14                             VIETNAM      1000
# 15                       INTERNATIONAL       301
# 16                       INTERNATIONAL       300
# 18                                EMEA      1000
# 19                                EMEA      1000
# 20                                EMEA      1000
# 21                                EMEA      1000
# 22                                EMEA      1000
# 23                                EMEA      1000
# 24                                EMEA      1000
# 25                                EMEA      1000
# 26                                EMEA      1000
# 27                                EMEA      1000
# 28                                EMEA      1000
# 29                                EMEA      1000
# 30                                EMEA      1000
# 31                               KOREA      1000
# 32                               JAPAN      1000
# 33                               KOREA      1000
# 34                              BRAZIL      1000
# 35                 LATIN AMERICA NORTH      1000
# 36                 LATIN AMERICA SOUTH      1000
#
#                                           tournaments
# 0   [{'id': '110303581083678395'}, {'id': '1095170...
# 1   [{'id': '110574243270525539'}, {'id': '1095186...
# 2   [{'id': '110894544221659776'}, {'id': '1107338...
# 3                      [{'id': '107898708099217418'}]
# 4   [{'id': '110413046183015975'}, {'id': '1095236...
# 5   [{'id': '110909366079472439'}, {'id': '1103715...
# 6   [{'id': '107417471555810057'}, {'id': '1062697...
# 7   [{'id': '109675608880518030'}, {'id': '1096756...
# 8   [{'id': '110848560874526298'}, {'id': '1104293...
# 9   [{'id': '110395308894756789'}, {'id': '1097102...
# 10  [{'id': '110411420269584926'}, {'id': '1096725...
# 11  [{'id': '110825936250664572'}, {'id': '1104288...
# 12  [{'id': '110847340080101648'}, {'id': '1104236...
# 13  [{'id': '110429898578299667'}, {'id': '1094671...
# 14  [{'id': '110416959491275651'}, {'id': '1097495...
# 15  [{'id': '110198981276611770'}, {'id': '1079052...
# 16  [{'id': '108998961191900167'}, {'id': '1069262...
# 18  [{'id': '110535609415063567'}, {'id': '1100164...
# 19  [{'id': '110424922266960422'}, {'id': '1094671...
# 20  [{'id': '110425082378454783'}, {'id': '1094672...
# 21  [{'id': '110424377524465827'}, {'id': '1094673...
# 22  [{'id': '110425027634430773'}, {'id': '1094673...
# 23  [{'id': '110444946767792846'}, {'id': '1095397...
# 24  [{'id': '110310652404523974'}, {'id': '1095398...
# 25  [{'id': '110349992504762921'}, {'id': '1094670...
# 26  [{'id': '110343648526792583'}, {'id': '1095397...
# 27  [{'id': '110444842958969834'}, {'id': '1094673...
# 28  [{'id': '110418013822985087'}, {'id': '1094672...
# 29  [{'id': '110428723804419399'}, {'id': '1094673...
# 30  [{'id': '110422923164198764'}, {'id': '1095457...
# 31                     [{'id': '108256075285852973'}]
# 32  [{'id': '110507407705819578'}, {'id': '1082169...
# 33  [{'id': '110378429156980338'}, {'id': '1096255...
# 34  [{'id': '110413232002702589'}, {'id': '1095236...
# 35                     [{'id': '110372140231846916'}]
# 36                     [{'id': '110372454557117766'}]

# %% [markdown]
# ## Tournaments Data

# %%
tournaments_df=pd.read_json('./esports-data/tournaments.json')
new_leagues_df=leagues_df[['id','name']].rename(columns={'id':'leagueId','name':'leagueName'})
new_tournaments=tournaments_df.merge(new_leagues_df,on='leagueId').sort_values(by='startDate',ascending=False)

# %%
new_tournaments.to_json('esports-data/tournaments-cleaned.json')

# %% [markdown]
# ## Mapping data

# %%
mapping_test=[]
with open('./esports-data/mapping_data.json') as f :
    mapping_data=json.load(f)

for entry in mapping_data:
    game_id=entry.get('esportsGameId')
    platformgameid=entry.get('platformGameId')
    teammapping=entry.get("teamMapping")
    red_team=teammapping.get('200')
    blue_team=teammapping.get('100')
    participantmapping=entry.get('participantMapping')
    dict_mapping={'esportsGameId': game_id ,'PlatformGameId': platformgameid, 'Red' : red_team, 'Blue' : blue_team}
    for participant_id, participant_info in participantmapping.items():
        dict_mapping[participant_id] = participant_info


    mapping_test.append(dict_mapping)
mapping_test_df=pd.DataFrame(mapping_test)

# %%
mapping_test_df.to_json('./esports-data/mapping_data_cleaned.json')

# %% [markdown]
# ## Stages

# %%
stage_value=new_tournaments.at[9,'stages']
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
#So, let's get every tournament's games and participants:
list_of_games = []
column_names = ['stageName','id','Red','Blue','winner']
for tour_stage in stage_value:
    #Iterating on both regular season and playoffs
    stage_name = tour_stage.get('name',None)
    stage_sections = tour_stage.get('sections',None)

    for stage_section in stage_sections:
        stage_matches = stage_section.get('matches',None)

        #If we have something and it isn't downright empty:
        for stage_match in stage_matches:
            stage_games = stage_match.get('games',None)

            if stage_games:
                for stage_game in stage_games:
                    #Only completed games matter
                    if stage_game.get('state',None) == 'completed':
                        game_id = stage_game.get('id',None)
                        game_red = None
                        game_blue = None
                        game_winner = None
                        for team in stage_game.get('teams',None):
                            game_red = team.get('id') if team.get('side') == 'red' else game_red
                            game_blue = team.get('id') if team.get('side') == 'blue' else game_blue
                            game_winner = team.get('side') if team.get('result').get('outcome') == 'win' else game_winner
                        list_of_games.append([stage_name,game_id,game_red,game_blue,game_winner])

stages_df = pd.DataFrame(list_of_games,columns=column_names)
# Out:
# [{'name': 'Regular Season',
#   'type': None,
#   'slug': 'regular_season',
#   'sections': [{'name': 'Regular Season',
#     'matches': [{'id': '109467311740709831',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521706535388095',
#         'side': 'blue',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740709832',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740709833',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '102787200149928963',
#         'side': 'blue',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]},
#        {'id': '105521706535388095',
#         'side': 'red',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740709834',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740709835',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521674055625312',
#         'side': 'blue',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]},
#        {'id': '105521706535388095',
#         'side': 'red',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740709836',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521674055625312',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740709837',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521706535388095',
#         'side': 'blue',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]},
#        {'id': '108078422885368642',
#         'side': 'red',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]}],
#       'games': [{'id': '109467311740709838',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '108078422885368642',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740709839',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '107067065368380132',
#         'side': 'blue',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]},
#        {'id': '105521706535388095',
#         'side': 'red',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740709840',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '107067065368380132',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775377',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '109671413728531527',
#         'side': 'blue',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]},
#        {'id': '105521706535388095',
#         'side': 'red',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775378',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '109671413728531527',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775379',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '105521706535388095',
#         'side': 'red',
#         'record': {'wins': 13, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775380',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775381',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '102787200149928963',
#         'side': 'blue',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775382',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775383',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521674055625312',
#         'side': 'blue',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775384',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521674055625312',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775385',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '108078422885368642',
#         'side': 'blue',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775386',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775387',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '107067065368380132',
#         'side': 'blue',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775388',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '107067065368380132',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775389',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521637552587612',
#         'side': 'blue',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]},
#        {'id': '109671413728531527',
#         'side': 'red',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775390',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '109671413728531527',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775391',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775392',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775393',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '102787200149928963',
#         'side': 'blue',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]},
#        {'id': '105521674055625312',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775394',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521674055625312',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775395',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '108078422885368642',
#         'side': 'blue',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775396',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775397',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '107067065368380132',
#         'side': 'blue',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775398',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '107067065368380132',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775399',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '109671413728531527',
#         'side': 'blue',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775400',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '109671413728531527',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775401',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775402',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775403',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '108078422885368642',
#         'side': 'blue',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]},
#        {'id': '105521674055625312',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775404',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521674055625312',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775405',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '107067065368380132',
#         'side': 'blue',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]},
#        {'id': '105521674055625312',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775406',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '107067065368380132',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521674055625312',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775407',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '109671413728531527',
#         'side': 'blue',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]},
#        {'id': '105521674055625312',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775408',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '109671413728531527',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521674055625312',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775409',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '105521674055625312',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}],
#       'games': [{'id': '109467311740775410',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521674055625312',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775411',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '108078422885368642',
#         'side': 'blue',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]},
#        {'id': '107067065368380132',
#         'side': 'red',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775412',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '107067065368380132',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775413',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '109671413728531527',
#         'side': 'blue',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]},
#        {'id': '108078422885368642',
#         'side': 'red',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775414',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '109671413728531527',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '108078422885368642',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775415',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '108078422885368642',
#         'side': 'red',
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775416',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '108078422885368642',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775417',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '107067065368380132',
#         'side': 'blue',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]},
#        {'id': '109671413728531527',
#         'side': 'red',
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775418',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '107067065368380132',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '109671413728531527',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775419',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 1},
#       'teams': [{'id': '105521293297166647',
#         'side': 'blue',
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 0},
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]},
#        {'id': '107067065368380132',
#         'side': 'red',
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 1},
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775420',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521293297166647',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '107067065368380132',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]}]},
#      {'id': '109467311740775421',
#       'type': 'normal',
#       'state': 'completed',
# ...
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}]},
#      {'ordinal': 3,
#       'teams': [{'id': '102787200149928963',
#         'side': None,
#         'record': {'wins': 9, 'losses': 5, 'ties': 0},
#         'result': None,
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}]},
#      {'ordinal': 4,
#       'teams': [{'id': '108078422885368642',
#         'side': None,
#         'record': {'wins': 7, 'losses': 7, 'ties': 0},
#         'result': None,
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]}]},
#      {'ordinal': 5,
#       'teams': [{'id': '107067065368380132',
#         'side': None,
#         'record': {'wins': 6, 'losses': 8, 'ties': 0},
#         'result': None,
#         'players': [{'id': '110654497896589061', 'role': 'top'},
#          {'id': '110654500696680230', 'role': 'jungle'},
#          {'id': '107065248397969613', 'role': 'support'},
#          {'id': '105521461654170052', 'role': 'support'},
#          {'id': '108448765407357094', 'role': 'top'},
#          {'id': '106425061853706320', 'role': 'jungle'},
#          {'id': '109517025487758872', 'role': 'mid'},
#          {'id': '105521213251945010', 'role': 'bottom'},
#          {'id': '107603213805511339', 'role': 'support'},
#          {'id': '109665683093858688', 'role': 'none'}]}]},
#      {'ordinal': 6,
#       'teams': [{'id': '109671413728531527',
#         'side': None,
#         'record': {'wins': 5, 'losses': 9, 'ties': 0},
#         'result': None,
#         'players': [{'id': '107065256938832257', 'role': 'top'},
#          {'id': '109665707587348884', 'role': 'bottom'},
#          {'id': '107633881734248402', 'role': 'mid'},
#          {'id': '107717697343044714', 'role': 'support'},
#          {'id': '110462561913944326', 'role': 'jungle'},
#          {'id': '110485490556229626', 'role': 'jungle'},
#          {'id': '107065257136226693', 'role': 'none'},
#          {'id': '106297390776740510', 'role': 'bottom'},
#          {'id': '107768042767707404', 'role': 'support'},
#          {'id': '108397470153119112', 'role': 'none'}]}]},
#      {'ordinal': 7,
#       'teams': [{'id': '105521293297166647',
#         'side': None,
#         'record': {'wins': 4, 'losses': 10, 'ties': 0},
#         'result': None,
#         'players': [{'id': '105521267488578852', 'role': 'jungle'},
#          {'id': '107450793732493452', 'role': 'mid'},
#          {'id': '108397470099882614', 'role': 'none'},
#          {'id': '107621049304382073', 'role': 'support'},
#          {'id': '105751319523372184', 'role': 'top'},
#          {'id': '109704513611127936', 'role': 'none'},
#          {'id': '110463022048401981', 'role': 'none'},
#          {'id': '105526526226325547', 'role': 'bottom'}]}]},
#      {'ordinal': 8,
#       'teams': [{'id': '105521674055625312',
#         'side': None,
#         'record': {'wins': 3, 'losses': 11, 'ties': 0},
#         'result': None,
#         'players': [{'id': '106301986540034560', 'role': 'top'},
#          {'id': '107065246868898096', 'role': 'mid'},
#          {'id': '103935390073272739', 'role': 'bottom'},
#          {'id': '106312668837258044', 'role': 'support'},
#          {'id': '109704767590976442', 'role': 'none'},
#          {'id': '107065249388860280', 'role': 'none'},
#          {'id': '110440840872642313', 'role': 'mid'},
#          {'id': '103766433331803330', 'role': 'jungle'},
#          {'id': '109665702844353777', 'role': 'mid'}]}]}]}]},
#  {'name': 'Playoffs',
#   'type': None,
#   'slug': 'playoffs',
#   'sections': [{'name': 'Playoffs',
#     'matches': [{'id': '109467311740775479',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 5},
#       'teams': [{'id': '105521706535388095',
#         'side': 'blue',
#         'record': {'wins': 1, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 3},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]},
#        {'id': '105521637552587612',
#         'side': 'red',
#         'record': {'wins': 0, 'losses': 2, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 2},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775480',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775481',
#         'state': 'completed',
#         'number': 2,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775482',
#         'state': 'completed',
#         'number': 3,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775483',
#         'state': 'completed',
#         'number': 4,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775484',
#         'state': 'completed',
#         'number': 5,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]}]},
#      {'id': '109467311740775485',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 5},
#       'teams': [{'id': '108078422885368642',
#         'side': 'blue',
#         'record': {'wins': 0, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 1},
#         'players': [{'id': '105548606962065935', 'role': 'support'},
#          {'id': '104738067226752196', 'role': 'top'},
#          {'id': '109923323442075597', 'role': 'top'},
#          {'id': '110440939840018618', 'role': 'jungle'},
#          {'id': '105521648113779564', 'role': 'mid'},
#          {'id': '104738172861178386', 'role': 'bottom'},
#          {'id': '105554067476698796', 'role': 'none'},
#          {'id': '107186942128466050', 'role': 'none'},
#          {'id': '107802421879699658', 'role': 'none'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 0, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 3},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775486',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740775487',
#         'state': 'completed',
#         'number': 2,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '108078422885368642',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775488',
#         'state': 'completed',
#         'number': 3,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775489',
#         'state': 'completed',
#         'number': 4,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'win'}},
#          {'id': '108078422885368642',
#           'side': 'red',
#           'result': {'outcome': 'loss'}}]},
#        {'id': '109467311740775490',
#         'state': 'unneeded',
#         'number': 5,
#         'teams': [{'id': '108078422885368642',
#           'side': 'blue',
#           'result': {'outcome': None}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': None}}]}]},
#      {'id': '109467311740775491',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 5},
#       'teams': [{'id': '105521637552587612',
#         'side': 'blue',
#         'record': {'wins': 0, 'losses': 2, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 1},
#         'players': [{'id': '104738067226752196', 'role': 'top'},
#          {'id': '107065248397969613', 'role': 'none'},
#          {'id': '107065248280215873', 'role': 'none'},
#          {'id': '105531045249475446', 'role': 'top'},
#          {'id': '106250634907345354', 'role': 'jungle'},
#          {'id': '105521714704604859', 'role': 'mid'},
#          {'id': '107065253176002809', 'role': 'bottom'},
#          {'id': '99591620723806690', 'role': 'support'},
#          {'id': '110440736606141174', 'role': 'none'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 0, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 3},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740775492',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740775493',
#         'state': 'completed',
#         'number': 2,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740775494',
#         'state': 'completed',
#         'number': 3,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740775495',
#         'state': 'completed',
#         'number': 4,
#         'teams': [{'id': '105521637552587612',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740775496',
#         'state': 'unneeded',
#         'number': 5,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': None}},
#          {'id': '105521637552587612',
#           'side': 'red',
#           'result': {'outcome': None}}]}]},
#      {'id': '109467311740841033',
#       'type': 'normal',
#       'state': 'completed',
#       'mode': 'classic',
#       'strategy': {'type': 'bestOf', 'count': 5},
#       'teams': [{'id': '105521706535388095',
#         'side': 'blue',
#         'record': {'wins': 1, 'losses': 1, 'ties': 0},
#         'result': {'outcome': 'loss', 'gameWins': 1},
#         'players': [{'id': '102787200035816046', 'role': 'bottom'},
#          {'id': '105554098262562524', 'role': 'support'},
#          {'id': '105515354716470535', 'role': 'top'},
#          {'id': '102418332506104195', 'role': 'jungle'},
#          {'id': '107614656149746484', 'role': 'mid'}]},
#        {'id': '102787200149928963',
#         'side': 'red',
#         'record': {'wins': 3, 'losses': 0, 'ties': 0},
#         'result': {'outcome': 'win', 'gameWins': 3},
#         'players': [{'id': '102787200023364184', 'role': 'support'},
#          {'id': '104738020689179820', 'role': 'jungle'},
#          {'id': '108362989061999316', 'role': 'top'},
#          {'id': '105589292050372795', 'role': 'mid'},
#          {'id': '101389713985551761', 'role': 'bottom'},
#          {'id': '103877979734184783', 'role': 'none'}]}],
#       'games': [{'id': '109467311740841034',
#         'state': 'completed',
#         'number': 1,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740841035',
#         'state': 'completed',
#         'number': 2,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740841036',
#         'state': 'completed',
#         'number': 3,
#         'teams': [{'id': '102787200149928963',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '105521706535388095',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740841037',
#         'state': 'completed',
#         'number': 4,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': 'loss'}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': 'win'}}]},
#        {'id': '109467311740841038',
#         'state': 'unneeded',
#         'number': 5,
#         'teams': [{'id': '105521706535388095',
#           'side': 'blue',
#           'result': {'outcome': None}},
#          {'id': '102787200149928963',
#           'side': 'red',
#           'result': {'outcome': None}}]}]}],
#     'rankings': []}]}]
